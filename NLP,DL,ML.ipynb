# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammedMujtabaAnsari/MACHINE-LEARNING-/blob/main/NLP%2CDL%2CML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
reviews=["I love this coffee","Service is off","Saff is rude"]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer()
x=cv.fit_transform(reviews)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(10, input_dim=x.shape[1], activation='relu'))
model.add(Dense(5, activation='relu'))
model.add(Dense(3, activation='softmax')) # Happy / Neutral / Angry
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical

# Assuming sentiment labels: 0 for positive, 1 for neutral, 2 for negative
# "I love this coffee" -> 0 (Positive)
# "Service is off" -> 2 (Negative)
# "Saff is rude" -> 2 (Negative)
labels = np.array([0, 2, 2])

# Convert integer labels to one-hot encoded format
num_classes = 3 # Based on the model's output layer
y = to_categorical(labels, num_classes=num_classes)

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x.toarray(), y, epochs=50)
# Out:
# Epoch 1/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.0000e+00 - loss: 1.1892
# Epoch 2/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0000e+00 - loss: 1.1787
# Epoch 3/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0000e+00 - loss: 1.1684
# Epoch 4/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0000e+00 - loss: 1.1582
# Epoch 5/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.0000e+00 - loss: 1.1481
# Epoch 6/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.0000e+00 - loss: 1.1381
# Epoch 7/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.0000e+00 - loss: 1.1281
# Epoch 8/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.0000e+00 - loss: 1.1183
# Epoch 9/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.0000e+00 - loss: 1.1086
# Epoch 10/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.0000e+00 - loss: 1.0990
# Epoch 11/50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.3333 - loss: 1.0895
# ...

# %%
from sklearn.naive_bayes import MultinomialNB

ml_model = MultinomialNB()
ml_model.fit(x, labels)
prediction = ml_model.predict(cv.transform(['I dont  a coffe']))
print(prediction)
# Out:
# [2]
